# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
plt.matshow(X_train[0])

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 986us/step - loss: 0.4748 - accuracy: 0.8758
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3043 - accuracy: 0.9153
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2840 - accuracy: 0.9208
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2733 - accuracy: 0.9238
# Epoch 5/5
# 1875/1875 [==============================] - 2s 862us/step - loss: 0.2669 - accuracy: 0.9261

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 0s 809us/step - loss: 0.2681 - accuracy: 0.9259
# [0.2680749297142029, 0.9258999824523926]

# %%
y_predicted = model.predict(X_test_flattened)
y_predicted[0]
# Out:
# 313/313 [==============================] - 0s 818us/step
# array([1.9995606e-02, 2.9307080e-07, 5.3248741e-02, 9.5662540e-01,
#        2.3032080e-03, 8.6604260e-02, 2.1465958e-06, 9.9970388e-01,
#        8.0354191e-02, 6.2184238e-01], dtype=float32)

# %%
plt.matshow(X_test[0])

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 964,    0,    2,    2,    0,    4,    4,    3,    1,    0],
#        [   0, 1111,    3,    2,    0,    1,    4,    2,   12,    0],
#        [   4,    8,  931,   20,    9,    1,   11,    9,   35,    4],
#        [   1,    0,   18,  941,    0,   11,    2,   12,   19,    6],
#        [   2,    1,    6,    2,  919,    0,    9,    4,   10,   29],
#        [  10,    3,    7,   55,   10,  749,    8,    8,   36,    6],
#        [  13,    3,    7,    1,    7,    9,  912,    2,    4,    0],
#        [   1,    5,   24,    7,    9,    0,    0,  948,    3,   31],
#        [   7,    6,    7,   30,    9,   18,    8,   12,  871,    6],
#        [  11,    7,    1,   13,   30,    5,    0,   23,    6,  913]])>

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
model = keras.Sequential([
    keras.layers.Dense(100, input_shape=(784,), activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2705 - accuracy: 0.9222
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1241 - accuracy: 0.9633
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0861 - accuracy: 0.9746
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0652 - accuracy: 0.9798
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0525 - accuracy: 0.9836

# %%
model.evaluate(X_test_flattened,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0784 - accuracy: 0.9755
# [0.07838346809148788, 0.9754999876022339]

# %%
y_predicted = model.predict(X_test_flattened)
y_predicted_labels = [np.argmax(i) for i in y_predicted]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# 313/313 [==============================] - 0s 1ms/step
# Text(95.72222222222221, 0.5, 'Truth')

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2729 - accuracy: 0.9213
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1266 - accuracy: 0.9628
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0880 - accuracy: 0.9735
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0676 - accuracy: 0.9800
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0533 - accuracy: 0.9836
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0437 - accuracy: 0.9864
# Epoch 7/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0354 - accuracy: 0.9894
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0296 - accuracy: 0.9907
# Epoch 9/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0238 - accuracy: 0.9929
# Epoch 10/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0203 - accuracy: 0.9938

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0880 - accuracy: 0.9766
# [0.08802963048219681, 0.9765999913215637]
